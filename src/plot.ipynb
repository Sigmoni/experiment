# %%
import matplotlib.pyplot as plt

# %%
x = ["SHIPDATE,COMMITDATE", "SHIPDATE,RECEIPTDATE", "COMMITDATE,RECEIPTDATE", "QUANTITY,SHIPMODE", "LINENUMBER,QUANTITY", "QUANTITY,TAX"]
gmq_iris = [1.97, 2.04, 1.94, 1.73, 2.99, 1.99]
gmq_ps8 = [2.12, 1.79, 1.96, 4.31, 3.13, 2.52]
gmq_ps16 = [1.43, 1.34, 1.39, 5.01, 2.35, 2.15]

# %%
plt.plot(x, gmq_iris, label="Iris")
plt.plot(x, gmq_ps8, label="Prefix-sum 8")
plt.plot(x, gmq_ps16, label="Prefix-sum 16")
plt.xticks(rotation=90)

plt.legend()
plt.show()

# %%
p95_iris =[221.29, 324.34, 152.37, 5.34, 598.87, 108.68]
p95_ps8 = [97.88, 42.87, 85.88, 1928.78, 519.16, 334.65]
p95_ps16 = [22.35, 11.31, 16.30, 1863.43, 370.70, 289.54]

# %%
plt.plot(x, p95_iris, label="Iris")
plt.plot(x, p95_ps8, label="Prefix-sum 8")
plt.plot(x, p95_ps16, label="Prefix-sum 16")
plt.xticks(rotation=90)

plt.legend()
plt.show()
